# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
ndm = df.copy()

# %%
fig, axis = plt.subplots(3, 2, figsize = (10,20))
print(sns.histplot(x='R&D Spend', ax = axis[0][0], data=df, kde=True))
print(sns.histplot(x='Administration', data=df, ax = axis[0][1], kde=True))
print(sns.histplot(x='Marketing Spend', data=df,ax = axis[1][0], kde=True))
print(sns.histplot(x='Profit', ax = axis[1][1],data=df, kde=True))
print(sns.histplot(x='State', ax = axis[2][0],data=df, kde=True))
# Out:
# Axes(0.125,0.653529;0.352273x0.226471)
# Axes(0.547727,0.653529;0.352273x0.226471)
# Axes(0.125,0.381765;0.352273x0.226471)
# Axes(0.547727,0.381765;0.352273x0.226471)
# Axes(0.125,0.11;0.352273x0.226471)

# %%
ndm_new = ndm.copy()

# %%
pd.unique(ndm["State"])
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
ndm = pd.get_dummies(df, columns=['State'], dtype=int)

# %%
ndm
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
ndm.isnull().sum()
# Out:
# R&D Spend           12
# Administration      18
# Marketing Spend      0
# Profit               0
# State_California     0
# State_Florida        0
# State_New York       0
# dtype: int64

# %%
mean_value = ndm["R&D Spend"].mean()
ndm["R&D Spend"].fillna(mean_value, inplace=True)
mean_value = ndm["Administration"].mean()
ndm["Administration"].fillna(mean_value, inplace=True)

# %%
ndm
# Out:
#         R&D Spend  Administration  Marketing Spend     Profit  \
# 0   165349.200000    136897.80000        471784.10  192261.83
# 1   162597.700000    151377.59000        443898.53  191792.06
# 2   153441.510000    101145.55000        407934.54  191050.39
# 3   144372.410000    118671.85000        383199.62  182901.99
# 4   142107.340000     91391.77000        366168.42  166187.94
# 5   131876.900000     99814.71000        362861.36  156991.12
# 6   134615.460000    147198.87000        127716.82  156122.51
# 7   130298.130000    145530.06000        323876.68  155752.60
# 8   120542.520000    148718.95000        311613.29  152211.77
# 9   123334.880000    108679.17000        304981.62  149759.96
# 10  101913.080000    110594.11000        229160.95  146121.95
# 11  100671.960000     91790.61000        249744.55  144259.40
# 12   93863.750000    127320.38000        249839.44  141585.52
# 13   91992.390000    135495.07000        252664.93  134307.35
# ...

# %%
X = ndm.copy()
Y = X.pop("Profit")

# %%
Y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,shuffle = True, random_state=13)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print(mean_squared_error(y_test, y_pred))
# Out:
# 222723144.06098422

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8732336264381823

# %%
ndm.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %%
max(ndm["R&D Spend"])
# Out:
# 165349.2

# %%
ndm["R&D Spend"] = ndm["R&D Spend"]/165349.2

# %%
max(ndm["Administration"])
# Out:
# 157693.92

# %%
ndm["Administration"] = ndm["Administration"]/157693.92

# %%
max(ndm["Marketing Spend"])
# Out:
# 471784.1

# %%
ndm["Marketing Spend"] = ndm["Marketing Spend"]/471784.1

# %%
max(ndm["Profit"])
# Out:
# 192261.83

# %%
ndm["Profit"] = ndm["Profit"]/192261.83

# %%
ndm
# Out:
#     R&D Spend  Administration  Marketing Spend    Profit  State_California  \
# 0    1.000000        0.868124         1.000000  1.000000                 0
# 1    0.983359        0.959946         0.940893  0.997557                 1
# 2    0.927985        0.641404         0.864664  0.993699                 0
# 3    0.873136        0.752546         0.812235  0.951317                 0
# 4    0.859438        0.579552         0.776136  0.864383                 0
# 5    0.797566        0.632965         0.769126  0.816549                 0
# 6    0.814128        0.933447         0.270710  0.812031                 1
# 7    0.788018        0.922864         0.686493  0.810107                 0
# 8    0.729018        0.943086         0.660500  0.791690                 0
# 9    0.745906        0.689178         0.646443  0.778938                 1
# 10   0.616351        0.701321         0.485733  0.760015                 0
# ...

# %%
X = ndm.copy()
Y = X.pop("Profit")

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,shuffle = True, random_state=13)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.006025307351518785

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8732336264381826

# %%
x_train.pop("State_California")
x_test.pop("State_California")
# Out:
# 43    0
# 4     0
# 20    1
# 46    0
# 0     0
# 14    0
# 36    0
# 28    0
# 24    0
# 6     1
# Name: State_California, dtype: int64

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.006025307351518798
# 0.8732336264381823

# %%
sns.heatmap(ndm.corr(), cmap="Blues", annot = True)
# Out:
# <Axes: >

# %%
ndm.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend    Profit  State_California  \
# 0   1.000000        0.868124         1.000000  1.000000                 0
# 1   0.983359        0.959946         0.940893  0.997557                 1
# 2   0.927985        0.641404         0.864664  0.993699                 0
# 3   0.873136        0.752546         0.812235  0.951317                 0
# 4   0.859438        0.579552         0.776136  0.864383                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %%
fig, axis = plt.subplots(3, 2, figsize = (10,20))
print(sns.histplot(x='R&D Spend', ax = axis[0][0], data=df, kde=True))
print(sns.histplot(x='Administration', data=df, ax = axis[0][1], kde=True))
print(sns.histplot(x='Marketing Spend', data=df,ax = axis[1][0], kde=True))
print(sns.histplot(x='Profit', ax = axis[1][1],data=df, kde=True))
print(sns.histplot(x='State', ax = axis[2][0],data=df, kde=True))
# Out:
# Axes(0.125,0.653529;0.352273x0.226471)
# Axes(0.547727,0.653529;0.352273x0.226471)
# Axes(0.125,0.381765;0.352273x0.226471)
# Axes(0.547727,0.381765;0.352273x0.226471)
# Axes(0.125,0.11;0.352273x0.226471)

# %%
sns.scatterplot(x = "Marketing Spend", y = "R&D Spend", data=ndm)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='R&D Spend'>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

columns_for_pca = ["Marketing Spend", "R&D Spend"]
data_for_pca = ndm[columns_for_pca]


scaler = StandardScaler()
data_standardized = scaler.fit_transform(data_for_pca)

# Apply PCA
pca = PCA(n_components=2) 
principal_components = pca.fit_transform(data_standardized)

# %%
explained_variance_ratio = pca.explained_variance_ratio_

print("Explained Variance Ratio:", explained_variance_ratio)


plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Profit and R&D Spend')
plt.show()
# Out:
# Explained Variance Ratio: [0.84925545 0.15074455]

# %%
X.pop("Marketing Spend")
X.pop("R&D Spend")
# Out:
# 0     1.000000
# 1     0.983359
# 2     0.927985
# 3     0.873136
# 4     0.859438
# 5     0.797566
# 6     0.814128
# 7     0.788018
# 8     0.729018
# 9     0.745906
# 10    0.616351
# 11    0.608845
# 12    0.567670
# 13    0.556352
# 14    0.725394
# 15    0.692617
# 16    0.471808
# 17    0.572468
# 18    0.554881
# 19    0.522650
# 20    0.461169
# 21    0.474084
# 22    0.447505
# 23    0.408424
# 24    0.465947
# 25    0.391080
# 26    0.455574
# 27    0.436093
# 28    0.399467
# 29    0.396769
# 30    0.374931
# 31    0.510869
# 32    0.510869
# 33    0.510869
# 34    0.510869
# 35    0.510869
# 36    0.510869
# 37    0.510869
# 38    0.510869
# 39    0.510869
# 40    0.510869
# 41    0.510869
# 42    0.142976
# 43    0.510869
# 44    0.134127
# 45    0.006049
# 46    0.007956
# 47    0.000000
# 48    0.003278
# 49    0.000000
# Name: R&D Spend, dtype: float64

# %%
X["R&D Spend + Marketing Spend"] = principal_components[:, 0]

# %%
X
# Out:
#     Administration  State_California  State_Florida  State_New York  \
# 0         0.868124                 0              0               1
# 1         0.959946                 1              0               0
# 2         0.641404                 0              1               0
# 3         0.752546                 0              0               1
# 4         0.579552                 0              1               0
# 5         0.632965                 0              0               1
# 6         0.933447                 1              0               0
# 7         0.922864                 0              1               0
# 8         0.943086                 0              0               1
# 9         0.689178                 1              0               0
# 10        0.701321                 0              1               0
# 11        0.582081                 1              0               0
# 12        0.807389                 0              1               0
# ...

# %%
X["R&D Spend + Marketing Spend"] = X["R&D Spend + Marketing Spend"]/max(X["R&D Spend + Marketing Spend"])
X.pop("State_California")
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
# 5     0
# 6     1
# 7     0
# 8     0
# 9     1
# 10    0
# 11    1
# 12    0
# 13    1
# 14    0
# 15    0
# 16    1
# 17    0
# 18    0
# 19    0
# 20    1
# 21    0
# 22    0
# 23    0
# 24    0
# 25    1
# 26    0
# 27    0
# 28    0
# 29    0
# 30    0
# 31    0
# 32    1
# 33    0
# 34    1
# 35    0
# 36    0
# 37    1
# 38    0
# 39    1
# 40    1
# 41    0
# 42    1
# 43    0
# 44    1
# 45    0
# 46    0
# 47    1
# 48    0
# 49    1
# Name: State_California, dtype: int64

# %%
X.head()
# Out:
#    Administration  State_Florida  State_New York  R&D Spend + Marketing Spend
# 0        0.868124              0               1                     1.000000
# 1        0.959946              0               0                     0.928118
# 2        0.641404              1               0                     0.802077
# 3        0.752546              0               1                     0.698913
# 4        0.579552              1               0                     0.651536

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,shuffle = True, random_state=13)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.01007363329036783
# 0.7880609425692386
